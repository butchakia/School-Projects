# %% [markdown]
# # DSCI 503 – Project 03
# ### Jeffery Boczkaja

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Loading the Dataset; Preliminary Analysis
# We will load the data into a DataFrame then explore the structure of the data set.

# %%
diamonds = pd.read_csv('C:/Users/whitl/OneDrive/Desktop/diamonds.txt', sep='\t')
diamonds.head(10)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 1    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 6    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 8    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 9    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# We will determine the size of the dataset

# %%
diamonds.shape
# Out:
# (53940, 10)

# %% [markdown]
# We will now inspect the distribution of the columns in diamonds.

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# ## Filtering and Sorting
# We will start by viewing information about the 5 most expensive diamonds in the dataset.

# %%
diamonds[['price', 'carat', 'cut', 'color', 'clarity']].sort_values('price', ascending=False).head(5)
# Out:
#        price  carat        cut color clarity
# 27750  18823   2.29    Premium     I     VS2
# 27749  18818   2.00  Very Good     G     SI1
# 27748  18806   1.51      Ideal     G      IF
# 27747  18804   2.07      Ideal     G     SI2
# 27746  18803   2.00  Very Good     H     SI1

# %% [markdown]
# We will now view information about the 5 least expensive diamonds in the dataset.

# %%
diamonds[['price', 'carat', 'cut', 'color', 'clarity']].sort_values('price', ascending=True).head(5)
# Out:
#    price  carat      cut color clarity
# 1    326   0.23    Ideal     E     SI2
# 2    326   0.21  Premium     E     SI1
# 3    327   0.23     Good     E     VS1
# 4    334   0.29  Premium     I     VS2
# 5    335   0.31     Good     J     SI2

# %% [markdown]
# We will now view information about the 5 largest diamonds in the dataset with an
# ideal cut.

# %%
diamonds[['price', 'carat', 'cut', 'color', 'clarity']][diamonds['cut'] == 'Ideal'].sort_values('carat', ascending=False).head(5)
# Out:
#        price  carat    cut color clarity
# 24329  12587   3.50  Ideal     H      I1
# 24298  12545   3.22  Ideal     I      I1
# 26468  16037   3.01  Ideal     J     SI2
# 26745  16538   3.01  Ideal     J      I1
# 24785  13156   2.75  Ideal     D      I1

# %% [markdown]
# We will now view information about the 5 largest diamonds in the dataset with an
# fair cut.

# %%
diamonds[['price', 'carat', 'cut', 'color', 'clarity']][diamonds['cut'] == 'Fair'].sort_values('carat', ascending=False).head(5)
# Out:
#        price  carat   cut color clarity
# 27416  18018   5.01  Fair     J      I1
# 27631  18531   4.50  Fair     J      I1
# 27131  17329   4.13  Fair     H      I1
# 23645  11668   3.65  Fair     H      I1
# 26432  15964   3.40  Fair     D      I1

# %% [markdown]
# ## Part 3: Working with Categorical Variables
# We will be creating lists to specify the order for each of the three categorical variables.

# %%
clarity_levels = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
cut_levels = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_levels = ['J', 'I', 'H', 'G', 'F', 'E', 'D']

# %% [markdown]
# We will now use these lists to communicate to Pandas the correct order for the
# levels of the three categorical variables.

# %%
diamonds['cut'] = pd.Categorical(diamonds['cut'], categories=['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], ordered=True)
diamonds['color'] = pd.Categorical(diamonds['color'], categories=['J', 'I', 'H', 'G', 'F', 'E', 'D'], ordered=True)
diamonds['clarity'] = pd.Categorical(diamonds['clarity'], categories=['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'], ordered=True)

# %% [markdown]
# We will now create lists of named colors to serve as palettes to be used for
# visualizations later in the notebook.

# %%
clarity_pal = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'purple', 'pink']
color_pal = ['brown', 'aqua', 'yellow', 'gold', 'blue', 'indigo', 'silver']
cut_pal = ['maroon', 'orange', 'gold', 'green', 'blue']

# %% [markdown]
# ## Part 4: Displaying Counts for Categorical Variables
# We will start by counting the number of diamonds for each level of cut.

# %%
diamonds['cut'].value_counts().sort_index()
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: cut, dtype: int64

# %% [markdown]
# We will now count the number of diamonds for each level of color.

# %%
diamonds['color'].value_counts().sort_index()
# Out:
# J     2808
# I     5422
# H     8304
# G    11292
# F     9542
# E     9797
# D     6775
# Name: color, dtype: int64

# %% [markdown]
# We will now count the number of diamonds for each level of clarity.

# %%
diamonds['clarity'].value_counts().sort_index()
# Out:
# I1        741
# SI2      9194
# SI1     13065
# VS2     12258
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# Name: clarity, dtype: int64

# %% [markdown]
# ## Part 5: Scatterplots of Price Against Carat
# We will explore the relationship between the price and carat attributes by generating scatter plots.

# %%
plt.figure(figsize=[8, 6])
plt.scatter(diamonds['carat'], diamonds['price'], s=20, alpha=0.4, color='blue', edgecolors='none')
plt.xlabel('Carat Size')
plt.ylabel('Price (in $)')
plt.title('Relationship between Diamond Price and Carat Size')
plt.show()

# %% [markdown]
# We will reproduce the plot from above, but will now color the points according to
# their clarity.

# %%
plt.figure(figsize=[8, 6])
for clarity, color in zip(clarity_levels, clarity_pal):
    plt.scatter(diamonds[diamonds['clarity'] == clarity]['carat'], diamonds[diamonds['clarity'] == clarity]['price'],
                s=20, alpha=0.4, color=color, edgecolors='none', label=clarity)
plt.xlabel('Carat Size')
plt.ylabel('Price (in $)')
plt.title('Relationship between Diamond Price and Carat Size')
plt.legend()
plt.show()

# %% [markdown]
# We will now separate the points for each of the eight clarity levels into its own
# subplot.

# %%
fig, axes = plt.subplots(2, 4, figsize=[12, 6])
for clarity, color, ax in zip(clarity_levels, clarity_pal, axes.flatten()):
    subset = diamonds[diamonds['clarity'] == clarity]
    ax.scatter(subset['carat'], subset['price'], s=20, alpha=0.4, color=color, edgecolors='none')
    ax.set_xlabel('Carat Size')
    ax.set_ylabel('Price (in $)')
    ax.set_title(clarity)
    ax.set_xlim([0, 4])
    ax.set_ylim([0, 20000])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 6: Applying Logarithmic Transformations
# We will apply logarithmic transformations to the price and carat columns, and will explore the distribution of
# these transformed variables.

# %%
diamonds['ln_carat'] = np.log(diamonds['carat'])
diamonds['ln_price'] = np.log(diamonds['price'])

# %% [markdown]
# We will now use histograms to explore the distribution of the diamond prices, and
# the log of the diamond prices.

# %%
fig, axs = plt.subplots(1, 2, figsize=[12, 4])
axs[0].hist(diamonds['price'], bins=20, edgecolor='black', color='violet')
axs[0].set_xlabel('Price')
axs[0].set_ylabel('Count')
axs[0].set_title('Histogram of Prices')
axs[1].hist(diamonds['ln_price'], bins=20, edgecolor='black', color='pink')
axs[1].set_xlabel('Natural Log of Price')
axs[1].set_ylabel('Count')
axs[1].set_title('Histogram of Log-Prices')
plt.tight_layout()
plt.show()

# %% [markdown]
# We will now use histograms to explore the distribution of the carat sizes, and the
# log of the carat sizes.

# %%
fig, axs = plt.subplots(1, 2, figsize=[12, 4])
axs[0].hist(diamonds['carat'], bins=20, edgecolor='black', color='red')
axs[0].set_xlabel('Carat Size')
axs[0].set_ylabel('Count')
axs[0].set_title('Histogram of Carat Sizes')
axs[1].hist(diamonds['ln_carat'], bins=20, edgecolor='black', color='orange')
axs[1].set_xlabel('Natural Log of Carat Size')
axs[1].set_ylabel('Count')
axs[1].set_title('Histogram of Log-Carat Sizes')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 7: Scatterplot of Transformed Variables
# We will create a scatterplot of ln_price against ln_carat, with points colored according to their
# clarity.

# %%
plt.figure(figsize=[8, 6])
for clarity, color in zip(clarity_levels, clarity_pal):
    plt.scatter(diamonds[diamonds['clarity'] == clarity]['ln_carat'], diamonds[diamonds['clarity'] == clarity]['ln_price'],
                s=20, alpha=0.4, color=color, edgecolors='none', label=clarity)
plt.xlabel('Natural Log of Carat Size')
plt.ylabel('Natural Log of Price')
plt.title('Relationship between Log-Price and Log-Carat Size')
plt.legend()
plt.show()

# %% [markdown]
# ## Part 8: Grouping by Cut
# We will create a grouped DataFrame displaying the mean price and carat size for each cut level.

# %%
gb_cut = diamonds[['cut', 'price', 'carat']].groupby('cut').mean()
gb_cut
# Out:
#                  price     carat
# cut
# Fair       4358.757764  1.046137
# Good       3928.864452  0.849185
# Very Good  3981.759891  0.806381
# Premium    4584.257704  0.891955
# Ideal      3457.541970  0.702837

# %% [markdown]
# We will now use bar charts to graphically display the information from the
# DataFrame above.

# %%
plt.figure(figsize=[12, 4])
plt.subplot(1, 2, 1)
plt.bar(gb_cut.index, gb_cut['price'], edgecolor='black', color=cut_pal)
plt.xlabel('Cut')
plt.ylabel('Mean Price')
plt.title('Mean Price by Cut')
plt.subplot(1, 2, 2)
plt.bar(gb_cut.index, gb_cut['carat'], edgecolor='black', color=cut_pal)
plt.xlabel('Cut')
plt.ylabel('Mean Carat Size')
plt.title('Mean Carat Size by Cut')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 9 Grouping by Color
# We will create a grouped DataFrame displaying the mean price and carat size for each color level.

# %%
gb_color = diamonds[['color', 'price', 'carat']].groupby('color').mean()
gb_color
# Out:
#              price     carat
# color
# J      5323.818020  1.162137
# I      5091.874954  1.026927
# H      4486.669196  0.911799
# G      3999.135671  0.771190
# F      3724.886397  0.736538
# E      3076.752475  0.657867
# D      3169.954096  0.657795

# %% [markdown]
# We will now use bar charts to graphically display the information from the
# DataFrame above.

# %%
plt.figure(figsize=[12, 4])
plt.subplot(1, 2, 1)
plt.bar(gb_color.index, gb_color['price'], edgecolor='black', color=color_pal)
plt.xlabel('Color')
plt.ylabel('Mean Price')
plt.title('Mean Price by Color')
plt.subplot(1, 2, 2)
plt.bar(gb_color.index, gb_color['carat'], edgecolor='black', color=color_pal)
plt.xlabel('Color')
plt.ylabel('Mean Carat Size')
plt.title('Mean Carat Size by Color')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 10 Grouping by Clarity
# We will create a grouped DataFrame displaying the mean price and carat size for each clarity level.

# %%
gb_clarity = diamonds[['clarity', 'price', 'carat']].groupby('clarity').mean()

# %% [markdown]
# We will now use bar charts to graphically display the information from the
# DataFrame above.

# %%
plt.figure(figsize=[12, 4])
plt.subplot(1, 2, 1)
plt.bar(gb_clarity.index, gb_clarity['price'], edgecolor='black', color=clarity_pal)
plt.xlabel('Clarity')
plt.ylabel('Mean Price')
plt.title('Mean Price by Clarity')
plt.subplot(1, 2, 2)
plt.bar(gb_clarity.index, gb_clarity['carat'], edgecolor='black', color=clarity_pal)
plt.xlabel('Clarity')
plt.ylabel('Mean Carat Size')
plt.title('Mean Carat Size by Clarity')
plt.tight_layout()
plt.show()
